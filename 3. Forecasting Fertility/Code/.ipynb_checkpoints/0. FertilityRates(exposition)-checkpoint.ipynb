# %%
import Pkg; Pkg.add("RCall")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Libmount_jll ────────────── v2.39.3+0
#    Installed JpegTurbo_jll ───────────── v3.0.2+0
#    Installed GR_jll ──────────────────── v0.73.3+0
#    Installed AbstractMCMC ────────────── v5.2.0
#    Installed MutableArithmetics ──────── v1.4.1
#    Installed Accessors ───────────────── v0.1.36
#    Installed Preferences ─────────────── v1.4.3
#    Installed NNlib ───────────────────── v0.9.12
#    Installed ConcurrentUtilities ─────── v2.4.1
#    Installed StableHashTraits ────────── v1.1.8
#    Installed StaticArrays ────────────── v1.9.3
#    Installed RCall ───────────────────── v0.14.1
#    Installed Formatting ──────────────── v0.4.3
#    Installed ProgressMeter ───────────── v1.10.0
#    Installed Roots ───────────────────── v2.1.5
#    Installed PlotUtils ───────────────── v1.4.1
#    Installed RecursiveArrayTools ─────── v3.12.0
#    Installed OpenSSL ─────────────────── v1.4.2
#    Installed Cairo_jll ───────────────── v1.18.0+1
#    Installed HTTP ────────────────────── v1.10.4
#    Installed FiniteDiff ──────────────── v2.23.0
#    Installed Functors ────────────────── v0.4.8
#    Installed FileIO ──────────────────── v1.16.3
#    Installed LLVM ────────────────────── v6.6.1
#    Installed Pango_jll ───────────────── v1.52.1+0
#    Installed WinReg ──────────────────── v1.0.0
#    Installed ADTypes ─────────────────── v0.2.7
#    Installed SciMLBase ───────────────── v2.30.0
#    Installed XZ_jll ──────────────────── v5.6.1+0
#    Installed MCMCDiagnosticTools ─────── v0.3.10
#    Installed ZeroMQ_jll ──────────────── v4.3.5+0
#    Installed Random123 ───────────────── v1.7.0
#    Installed TranscodingStreams ──────── v0.10.4
#    Installed DynamicPPL ──────────────── v0.24.9
#    Installed DataStructures ──────────── v0.18.18
#    Installed MathOptInterface ────────── v1.27.0
#    Installed Compat ──────────────────── v4.14.0
#    Installed Tracker ─────────────────── v0.2.32
#    Installed GridLayoutBase ──────────── v0.10.2
#    Installed libpng_jll ──────────────── v1.6.43+1
#    Installed Libtask ─────────────────── v0.8.7
#    Installed SciMLStructures ─────────── v1.1.0
#    Installed SimplePartitions ────────── v0.3.2
#    Installed Format ──────────────────── v1.3.6
#    Installed SciMLOperators ──────────── v0.3.8
#    Installed LLVMExtra_jll ───────────── v0.0.29+0
#    Installed AbstractPPL ─────────────── v0.7.1
#    Installed AdvancedMH ──────────────── v0.8.1
#    Installed AbstractTrees ───────────── v0.4.5
#    Installed ChainRulesCore ──────────── v1.23.0
#    Installed LogExpFunctions ─────────── v0.3.27
#    Installed ArrayInterface ──────────── v7.9.0
#    Installed GR ──────────────────────── v0.73.3
#    Installed Libuuid_jll ─────────────── v2.39.3+1
#    Installed Adapt ───────────────────── v4.0.3
#    Installed InverseFunctions ────────── v0.1.13
#    Installed XML2_jll ────────────────── v2.12.5+0
#    Installed KernelAbstractions ──────── v0.9.18
#    Installed IntervalSets ────────────── v0.7.10
#    Installed IntervalArithmetic ──────── v0.22.9
#    Installed Primes ──────────────────── v0.5.6
#    Installed Glib_jll ────────────────── v2.80.0+0
#    Installed StructArrays ────────────── v0.6.18
#    Installed Latexify ────────────────── v0.16.2
#    Installed SymbolicIndexingInterface ─ v0.3.11
#    Installed PrecompileTools ─────────── v1.2.1
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [6f49c342] + RCall v0.14.1
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [47edcb42] ↑ ADTypes v0.2.6 ⇒ v0.2.7
#   [80f14c24] ↑ AbstractMCMC v5.0.0 ⇒ v5.2.0
#   [7a57a42e] ↑ AbstractPPL v0.7.0 ⇒ v0.7.1
#   [1520ce14] ↑ AbstractTrees v0.4.4 ⇒ v0.4.5
#   [7d9f7c33] ↑ Accessors v0.1.35 ⇒ v0.1.36
#   [79e6a3ab] ↑ Adapt v4.0.1 ⇒ v4.0.3
#   [5b7e9947] ↑ AdvancedMH v0.8.0 ⇒ v0.8.1
#   [4fba245c] ↑ ArrayInterface v7.7.0 ⇒ v7.9.0
#   [d360d2e6] ↑ ChainRulesCore v1.21.1 ⇒ v1.23.0
#   [34da2185] ↑ Compat v4.12.0 ⇒ v4.14.0
#   [f0e56b4a] ↑ ConcurrentUtilities v2.3.1 ⇒ v2.4.1
#   [864edb3b] ↑ DataStructures v0.18.16 ⇒ v0.18.18
#   [366bfd00] ↑ DynamicPPL v0.24.5 ⇒ v0.24.9
#   [5789e2e9] ↑ FileIO v1.16.2 ⇒ v1.16.3
#   [6a86dc24] ↑ FiniteDiff v2.22.0 ⇒ v2.23.0
#   [1fa38f19] + Format v1.3.6
#   [59287772] ↑ Formatting v0.4.2 ⇒ v0.4.3
#   [d9f16b24] ↑ Functors v0.4.7 ⇒ v0.4.8
#   [28b8d3ca] ↑ GR v0.73.2 ⇒ v0.73.3
#   [3955a311] ↑ GridLayoutBase v0.10.0 ⇒ v0.10.2
#   [cd3eb016] ↑ HTTP v1.10.1 ⇒ v1.10.4
#   [d1acc4aa] ↑ IntervalArithmetic v0.22.7 ⇒ v0.22.9
#   [8197267c] ↑ IntervalSets v0.7.9 ⇒ v0.7.10
#   [3587e190] ↑ InverseFunctions v0.1.12 ⇒ v0.1.13
#   [63c18a36] ↑ KernelAbstractions v0.9.16 ⇒ v0.9.18
#   [929cbde3] ↑ LLVM v6.5.0 ⇒ v6.6.1
#   [23fbe1c1] ↑ Latexify v0.16.1 ⇒ v0.16.2
#   [50d2b5c4] - Lazy v0.15.1
#   [6f1fad26] ↑ Libtask v0.8.6 ⇒ v0.8.7
#   [2ab3a3ac] ↑ LogExpFunctions v0.3.26 ⇒ v0.3.27
#   [be115224] ↑ MCMCDiagnosticTools v0.3.8 ⇒ v0.3.10
#   [b8f27783] ↑ MathOptInterface v1.25.2 ⇒ v1.27.0
#   [d8a4904e] ↑ MutableArithmetics v1.4.0 ⇒ v1.4.1
#   [872c559c] ↑ NNlib v0.9.11 ⇒ v0.9.12
#   [4d8831e6] ↑ OpenSSL v1.4.1 ⇒ v1.4.2
#   [995b91a9] ↑ PlotUtils v1.4.0 ⇒ v1.4.1
#   [aea7be01] ↑ PrecompileTools v1.2.0 ⇒ v1.2.1
#   [21216c6a] ↑ Preferences v1.4.1 ⇒ v1.4.3
#   [27ebfcd6] ↑ Primes v0.5.5 ⇒ v0.5.6
#   [92933f4c] ↑ ProgressMeter v1.9.0 ⇒ v1.10.0
#   [6f49c342] + RCall v0.14.1
#   [74087812] ↑ Random123 v1.6.2 ⇒ v1.7.0
#   [731186ca] ↑ RecursiveArrayTools v3.8.1 ⇒ v3.12.0
#   [f2b01f46] ↑ Roots v2.1.2 ⇒ v2.1.5
#   [0bca4576] ↑ SciMLBase v2.24.0 ⇒ v2.30.0
#   [c0aeaf25] ↑ SciMLOperators v0.3.7 ⇒ v0.3.8
#   [53ae85a6] + SciMLStructures v1.1.0
#   [ec83eff0] ↑ SimplePartitions v0.3.1 ⇒ v0.3.2
#   [c5dd0088] ↑ StableHashTraits v1.1.7 ⇒ v1.1.8
#   [90137ffa] ↑ StaticArrays v1.9.2 ⇒ v1.9.3
#   [09ab397b] ↑ StructArrays v0.6.17 ⇒ v0.6.18
#   [2efcf032] ↑ SymbolicIndexingInterface v0.3.5 ⇒ v0.3.11
#   [9f7883ad] ↑ Tracker v0.2.31 ⇒ v0.2.32
#   [3bb67fe8] ↑ TranscodingStreams v0.10.3 ⇒ v0.10.4
#   [410a4b4d] - Tricks v0.1.8
#   [781d530d] - TruncatedStacktraces v1.4.0
#   [1b915085] + WinReg v1.0.0
#   [83423d85] ↑ Cairo_jll v1.16.1+1 ⇒ v1.18.0+1
#   [d2c73de3] ↑ GR_jll v0.73.2+0 ⇒ v0.73.3+0
#   [7746bdde] ↑ Glib_jll v2.76.5+0 ⇒ v2.80.0+0
#   [aacddb02] ↑ JpegTurbo_jll v3.0.1+0 ⇒ v3.0.2+0
#   [dad2f222] ↑ LLVMExtra_jll v0.0.28+0 ⇒ v0.0.29+0
#   [4b2f31a3] ↑ Libmount_jll v2.35.0+0 ⇒ v2.39.3+0
#   [38a345b3] ↑ Libuuid_jll v2.36.0+0 ⇒ v2.39.3+1
#   [36c8627f] ↑ Pango_jll v1.50.14+0 ⇒ v1.52.1+0
#   [02c8fc9c] ↑ XML2_jll v2.12.2+0 ⇒ v2.12.5+0
#   [ffd25f8a] ↑ XZ_jll v5.4.5+0 ⇒ v5.6.1+0
#   [8f1865be] ↑ ZeroMQ_jll v4.3.4+0 ⇒ v4.3.5+0
#   [b53b4c65] ↑ libpng_jll v1.6.40+0 ⇒ v1.6.43+1
#     Building RCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/846b2aab2d312fda5e7b099fc217c661e8fae27e/build.log`
# Precompiling project...
#   ✓ WinReg
#   ✓ ADTypes
#   ✓ InverseFunctions
#   ✓ ConcurrentUtilities
#   ✓ Format
#   ✓ Compat
#   ✓ Preferences
#   ✓ IntervalSets
#   ✓ AbstractTrees
#   ✓ SciMLStructures
#   ✓ Adapt
#   ✓ TranscodingStreams
#   ✓ ProgressMeter
#   ✓ Formatting
#   ✓ LogExpFunctions
#   ✓ SymbolicIndexingInterface
#   ✓ Primes
#   ✓ Functors
#   ✓ Libtask
#   ✓ InverseFunctions → DatesExt
#   ✓ Random123
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ PrecompileTools
#   ✓ FileIO
#   ✓ Libmount_jll
#   ✓ libpng_jll
#   ✓ Latexify
#   ✓ JpegTurbo_jll
#   ✓ XZ_jll
#   ✓ LLVMExtra_jll
#   ✓ ZeroMQ_jll
#   ✓ Libuuid_jll
#   ✓ MutableArithmetics
#   ✓ TranscodingStreams → TestExt
#   ✓ XML2_jll
#   ✓ ChainRulesCore
#   ✓ OpenSSL
#   ✓ DataStructures
#   ✓ IntervalArithmetic
#   ✓ StableHashTraits
#   ✓ libsixel_jll
#   ✓ IntervalSets → IntervalSetsRecipesBaseExt
#   ✓ Libtiff_jll
#   ✓ LightXML
#   ✓ EzXML
#   ✓ Gettext_jll
#   ✓ Fontconfig_jll
#   ✓ StaticArrays
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ XSLT_jll
#   ✓ LLVM
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ SimplePartitions
#   ✓ IntervalSets → IntervalSetsStatisticsExt
#   ✓ XLSX
#   ✓ StaticArrays → StaticArraysStatisticsExt
#   ✓ Glib_jll
#   ✓ StructArrays
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ HTTP
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ Accessors
#   ✓ ArrayInterface
#   ✓ Cairo_jll
#   ✓ LogExpFunctions → LogExpFunctionsChangesOfVariablesExt
#   ✓ StructArrays → StructArraysGPUArraysCoreExt
#   ✓ Accessors → AccessorsIntervalSetsExt
#   ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#   ✓ HarfBuzz_jll
#   ✓ KernelAbstractions
#   ✓ Qt6Base_jll
#   ✓ Polynomials → PolynomialsMutableArithmeticsExt
#   ✓ AbstractMCMC
#   ✓ PlotUtils
#   ✓ Sixel
#   ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#   ✓ PNGFiles
#   ✓ StructArrays → StructArraysStaticArraysExt
#   ✓ Accessors → AccessorsStructArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ libass_jll
#   ✓ Pango_jll
#   ✓ NNlib
#   ✓ SimplePolynomials
#   ✓ MCMCDiagnosticTools
#   ✓ JpegTurbo
#   ✓ AbstractPPL
#   ✓ AdvancedMH
#   ✓ IntervalArithmetic → IntervalArithmeticRecipesBaseExt
#   ✓ StructArrays → StructArraysSparseArraysExt
#   ✓ PlotThemes
#   ✓ Accessors → AccessorsStaticArraysExt
#   ✓ RecipesPipeline
#   ✓ Cairo
#   ✓ LinearAlgebraX
#   ✓ FFMPEG_jll
#   ✓ Tracker
#   ✓ ExactPredicates
#   ✓ StructArrays → StructArraysAdaptExt
#   ✓ FFMPEG
#   ✓ Accessors → AccessorsUnitfulExt
#   ✓ Tracker → TrackerPDMatsExt
#   ✓ GR_jll
#   ✓ ArrayInterface → ArrayInterfaceTrackerExt
#   ✓ Latexify → DataFramesExt
#   ✓ LogDensityProblemsAD → LogDensityProblemsADForwardDiffBenchmarkToolsExt
#   ✓ Roots
#   ✓ GR
#   ✓ UnitfulLatexify
#   ✓ Roots → RootsForwardDiffExt
#   ✓ ArrayInterface → ArrayInterfaceChainRulesExt
#   ✓ GridLayoutBase
#   ✓ FiniteDiff
#   ✓ SciMLOperators
#   ✓ AdvancedMH → AdvancedMHMCMCChainsExt
#   ✓ RecursiveArrayTools
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
#   ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#   ✓ AdvancedMH → AdvancedMHForwardDiffExt
#   ✓ NLSolversBase
#   ✓ AdvancedMH → AdvancedMHStructArraysExt
#   ✓ RecursiveArrayTools → RecursiveArrayToolsTrackerExt
#   ✓ LineSearches
#   ✓ SciMLBase
#   ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#   ✓ DynamicPPL
#   ✓ DynamicPPL → DynamicPPLZygoteRulesExt
#   ✓ DynamicPPL → DynamicPPLMCMCChainsExt
#   ✓ MathOptInterface
#   ✓ DynamicPPL → DynamicPPLForwardDiffExt
#   ✓ Optim
#   ✓ SimpleGraphs
#   ✓ DelaunayTriangulation
#   ✓ Plots
#   ✓ Plots → FileIOExt
#   ✓ Plots → UnitfulExt
#   ✓ Plots → GeometryBasicsExt
#   ✓ Plots → IJuliaExt
#   ✓ StatsPlots
#   ✓ Makie
#   ✓ SciMLBase → SciMLBaseMakieExt
#   ✓ SciMLBase → SciMLBaseRCallExt
#   ✓ CairoMakie
#   ✓ AlgebraOfGraphics
#   ? Turing → TuringOptimExt
#   ✓ GLMakie
#   146 dependencies successfully precompiled in 179 seconds. 358 already precompiled.
#   64 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   1 dependency failed but may be precompilable after restarting julia
#   3 dependencies had output during precompilation:
# ┌ Formatting
# │  ┌ Warning: DEPRECATION NOTICE
# │  │
# │  │ Formatting.jl has been unmaintained for a while, with some serious
# │  │ correctness bugs compromising the original purpose of the package. As a result,
# │  │ it has been deprecated - consider using an alternative, such as
# │  │ `Format.jl` (https://github.com/JuliaString/Format.jl) or the `Printf` stdlib directly.
# │  │
# │  │ If you are not using Formatting.jl as a direct dependency, please consider
# │  │ opening an issue on any packages you are using that do use it as a dependency.
# │  │ From Julia 1.9 onwards, you can query `]why Formatting` to figure out which
# │  │ package originally brings it in as a dependency.
# │  └ @ Formatting ~/.julia/packages/Formatting/3VxOt/src/Formatting.jl:12
# └
# ┌ Turing → TuringOptimExt
# │  WARNING: Method definition ADgradient(ADTypes.AutoForwardDiff{chunksize, T} where T where chunksize, DynamicPPL.LogDensityFunction{V, M, C} where C where M where V) in module DynamicPPLForwardDiffExt at /Users/felipesanchez/.julia/packages/DynamicPPL/pg70d/ext/DynamicPPLForwardDiffExt.jl:16 overwritten in module Essential at /Users/felipesanchez/.julia/packages/Turing/IvHgW/src/essential/ad.jl:23.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ AdvancedMH → AdvancedMHMCMCChainsExt
# │  WARNING: method definition for checkbounds at /Users/felipesanchez/.julia/packages/Interpolations/USkTk/src/Interpolations.jl:454 declares type variable N but does not use it.
# │  WARNING: method definition for checkbounds at /Users/felipesanchez/.julia/packages/Interpolations/USkTk/src/Interpolations.jl:457 declares type variable N but does not use it.
# │  WARNING: method definition for GriddedInterpolation at /Users/felipesanchez/.julia/packages/Interpolations/USkTk/src/gridded/gridded.jl:37 declares type variable pad but does not use it.
# │  WARNING: method definition for GriddedInterpolation at /Users/felipesanchez/.julia/packages/Interpolations/USkTk/src/gridded/gridded.jl:60 declares type variable pad but does not use it.
# │  WARNING: method definition for interpolate! at /Users/felipesanchez/.julia/packages/Interpolations/USkTk/src/deprecations.jl:30 declares type variable TWeights but does not use it.
# └

# %%
using Turing, Distributions, RData, RCall, CSV, DataFrames, LinearAlgebra
# Function to filter out the specified age groups
function exclude_age_groups(df, ages_to_exclude)
    filter(row -> !(row[:age] in ages_to_exclude), df)
end

function replace_age_groups(dfs, age_map)
    for df in dfs
        df[!, :age] = [get(age_map, age, "0") for age in df[:, :age]]
    end
    return dfs
end

# Function to replace year with index
function replace_year_with_index(df)
    df[!, :year] = [year_to_index[year] for year in df[:, :year]]
    return df
end

# Function to unstack a DataFrame
function unstack_dataframe(df)
    # You might need to adjust the identifier columns as per your DataFrame structure
    identifier_cols = [:education, :age]
    return unstack(df, identifier_cols, :year, :pop)
end
# Out:
# unstack_dataframe (generic function with 1 method)

# %%
#Import rates
#mxjuliav1 and mxjuliav2 are created here
#/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year
#/Chapter Mortality/ModellingM/Code/2. BayesianLC/0. Main File BLC.R

path1 = "/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/fxjuliav1.RData"
rates1 = load(path1)

# Assigning 'mxjuliav' from 'rates'
fxjuliav1 = rates1["fxjuliav1"]
# Create an ordered list of keys as per your specified order
ordered_keys = [
    "No Education",
    "Primary",
    "Secondary",
    "Post Secondary"
]
# Ordered dataframe using the dictionary
fxjuliav1 = [fxjuliav1[key] for key in ordered_keys]

# Age groups to exclude
ages_to_exclude = ["15--19", "20--24", "55--59", "60--64", "65--69", "70--74", "75+"]
# Apply the filtering to each element in mxjuliav1
fxjuliav1 = [exclude_age_groups(df, ages_to_exclude) for df in fxjuliav1]

# Define the age mapping
age_map = Dict(
    "25--29" => "1",
    "30--34" => "2",
    "35--39" => "3",
    "40--44" => "4",
    "45--49" => "5",
    "50--54" => "6"
)
# Assuming mxjuliav1 is a list (or vector) of DataFrames
fxjuliav1 = replace_age_groups(fxjuliav1, age_map)

# Create a mapping from year to index
year_to_index = Dict(1998:2018 .=> 1:21)
# Apply the function to each DataFrame in your vector
fxjuliav1 = [replace_year_with_index(df) for df in fxjuliav1]

# Iterate through each DataFrame in the vector and drop 'mortality' and 'mx' columns
for df in fxjuliav1
    select!(df, Not([:fertility, :fx]))
end

# Unstack each DataFrame in mxjuliav1
fxjuliav1_wide = [unstack_dataframe(df) for df in fxjuliav1]
    
    # Iterate through each DataFrame in the vector and drop 'mortality' and 'mx' columns
for df in fxjuliav1_wide
    select!(df, Not([ :education, :age]))
end

# %%
fxjuliav1_wide
# Out:
# 4-element Vector{DataFrame}:
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  290.87    172.593   111.336    78.081    59.53     49.343    44.463    ⋯
#    2 │  322.825   186.385   117.8      81.501    61.727    51.177    46.448
#    3 │  337.33    197.65    127.889    91.384    72.111    62.839    60.472
#    4 │  367.162   256.987   188.307   144.452   116.006    97.531    85.843
#    5 │  364.258   238.759   167.778   126.396   102.084    88.39     82.049    ⋯
#    6 │  326.399   221.568   160.314   123.634   101.627    89.04     83.151
#                                                               14 columns omitted
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  629.577   570.607   523.78    486.949   458.502   437.242   422.305    ⋯
#    2 │  656.002   620.12    587.964   559.155   533.357   510.281   489.673
#    3 │  573.414   573.289   571.394   567.748   562.384   555.351   546.713
#    4 │  463.292   466.887   471.538   477.276   484.139   492.173   501.434
#    5 │  365.088   403.688   438.054   466.491   487.52    500.006   503.259    ⋯
#    6 │  297.757   342.958   386.077   424.775   456.771   480.055   493.102
#                                                               14 columns omitted
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  515.838   606.48    700.061   793.36    882.717   964.246  1034.12   1 ⋯
#    2 │  434.244   518.131   603.313   685.557   760.225   822.693   868.823
#    3 │  371.165   466.286   564.132   657.283   737.508   796.938   829.326
#    4 │  247.024   331.18    425.045   522.219   614.209   691.553   745.386
#    5 │  154.046   207.147   268.878   336.884   407.431   475.638   535.979    ⋯
#    6 │   97.316   129.442   166.782   208.164   251.677   294.758   334.403
#                                                               14 columns omitted
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  163.965   169.112   172.384   173.67    172.924   170.171   165.508    ⋯
#    2 │  173.682   177.848   180.736   182.279   182.444   181.227   178.655
#    3 │  157.622   149.233   143.512   140.182   139.084   140.165   143.477
#    4 │  122.391   119.229   118.039   118.763   121.437   126.191   133.266
#    5 │   79.852    81.93     85.117    89.54     95.377   102.87    112.346    ⋯
#    6 │   38.546    42.652    47.391    52.873    59.232    66.63     75.261
#                                                               14 columns omitted

# %%
fxjuliav1
# Out:
# DictoVec{DataFrame}("No Education"=>168×6 DataFrame
#  Row │ year     age     education     fertility  pop      fx
#      │ Float64  String  String        Float64    Float64  Float64
# ─────┼───────────────────────────────────────────────────────────────
#    1 │  1998.0  15--19  No Education    29437.0  222.863   4.88345
#    2 │  1998.0  20--24  No Education    36069.0  254.785   4.95277
#    3 │  1998.0  25--29  No Education    29648.0  290.87    4.62427
#    4 │  1998.0  30--34  No Education    20694.0  322.825   4.16049
#    5 │  1998.0  35--39  No Education    13516.0  337.33    3.69057
#    6 │  1998.0  40--44  No Education     4825.0  367.162   2.57576
#    7 │  1998.0  45--49  No Education      609.0  364.258   0.513956
#    8 │  1998.0  50--54  No Education       41.0  326.399  -2.07455
#    9 │  1999.0  15--19  No Education    30378.0  146.271   5.33601
#   10 │  1999.0  20--24  No Education    36744.0  160.9     5.43095
#   11 │  1999.0  25--29  No Education    30199.0  172.593   5.16463
#   ⋮  │    ⋮       ⋮          ⋮            ⋮         ⋮         ⋮
#  159 │  2017.0  45--49  No Education       93.0   71.603   0.261463
#  160 │  2017.0  50--54  No Education        4.0   93.151  -3.14793
#  161 │  2018.0  15--19  No Education     1483.0   30.048   3.89903
#  162 │  2018.0  20--24  No Education     2108.0   36.175   4.06513
#  163 │  2018.0  25--29  No Education     2006.0   43.584   3.82921
#  164 │  2018.0  30--34  No Education     1798.0   53.592   3.51303
#  165 │  2018.0  35--39  No Education     1337.0   60.981   3.08762
#  166 │  2018.0  40--44  No Education      542.0   69.871   2.04862
#  167 │  2018.0  45--49  No Education       77.0   78.107  -0.0142743
#  168 │  2018.0  50--54  No Education       13.0   92.077  -1.95768
#                                                      147 rows omitted,"Post Secondary"=>126×6 DataFrame
#  Row │ year     age     education       fertility  pop      fx
#      │ Float64  String  String          Float64    Float64  Float64
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │  1998.0  25--29  Post Secondary    13271.0  163.965   4.39368
#    2 │  1998.0  30--34  Post Secondary    14646.0  173.682   4.4347
#    3 │  1998.0  35--39  Post Secondary     7021.0  157.622   3.79646
#    4 │  1998.0  40--44  Post Secondary     1228.0  122.391   2.30592
#    5 │  1998.0  45--49  Post Secondary       49.0   79.852  -0.488355
#    6 │  1998.0  50--54  Post Secondary       17.0   38.546  -0.818639
#    7 │  1999.0  25--29  Post Secondary    14062.0  169.112   4.42067
#    8 │  1999.0  30--34  Post Secondary    15084.0  177.848   4.44046
#    9 │  1999.0  35--39  Post Secondary     7699.0  149.233   3.94334
#   10 │  1999.0  40--44  Post Secondary     1376.0  119.229   2.44589
#   11 │  1999.0  45--49  Post Secondary       58.0   81.93   -0.345422
#   ⋮  │    ⋮       ⋮           ⋮             ⋮         ⋮         ⋮
#  117 │  2017.0  35--39  Post Secondary    22303.0  393.516   4.03735
#  118 │  2017.0  40--44  Post Secondary     4264.0  316.215   2.60154
#  119 │  2017.0  45--49  Post Secondary      269.0  259.789   0.0348416
#  120 │  2017.0  50--54  Post Secondary       34.0  227.677  -1.90157
#  121 │  2018.0  25--29  Post Secondary    51267.0  675.023   4.33006
#  122 │  2018.0  30--34  Post Secondary    41195.0  595.457   4.23674
#  123 │  2018.0  35--39  Post Secondary    22775.0  524.51    3.77095
#  124 │  2018.0  40--44  Post Secondary     4482.0  407.285   2.39831
#  125 │  2018.0  45--49  Post Secondary      252.0  326.435  -0.258802
#  126 │  2018.0  50--54  Post Secondary       46.0  294.309  -1.85599
#                                                        105 rows omitted,"Primary"=>168×6 DataFrame
#  Row │ year     age     education  fertility  pop       fx
#      │ Float64  String  String     Float64    Float64   Float64
# ─────┼─────────────────────────────────────────────────────────────
#    1 │  1998.0  15--19  Primary      90470.0  1280.07    4.2581
#    2 │  1998.0  20--24  Primary      94295.0   578.642   5.0935
#    3 │  1998.0  25--29  Primary      68545.0   629.577   4.6902
#    4 │  1998.0  30--34  Primary      42729.0   656.002   4.17647
#    5 │  1998.0  35--39  Primary      20618.0   573.414   3.58231
#    6 │  1998.0  40--44  Primary       4577.0   463.292   2.29044
#    7 │  1998.0  45--49  Primary        346.0   365.088  -0.0536996
#    8 │  1998.0  50--54  Primary         55.0   297.757  -1.68894
#    9 │  1999.0  15--19  Primary      96359.0  1099.29    4.47341
#   10 │  1999.0  20--24  Primary      97309.0   529.857   5.21304
#   11 │  1999.0  25--29  Primary      68591.0   570.607   4.78922
#   ⋮  │    ⋮       ⋮         ⋮          ⋮         ⋮          ⋮
#  159 │  2017.0  45--49  Primary        409.0   770.612  -0.63347
#  160 │  2017.0  50--54  Primary         44.0   764.657  -2.85524
#  161 │  2018.0  15--19  Primary      71047.0   948.859   4.31584
#  162 │  2018.0  20--24  Primary      60153.0   485.207   4.82007
#  163 │  2018.0  25--29  Primary      39731.0   489.492   4.39652
#  164 │  2018.0  30--34  Primary      26110.0   539.442   3.87954
#  165 │  2018.0  35--39  Primary      15012.0   583.932   3.24682
#  166 │  2018.0  40--44  Primary       4772.0   634.105   2.01831
#  167 │  2018.0  45--49  Primary        395.0   703.289  -0.576882
#  168 │  2018.0  50--54  Primary         30.0   736.157  -3.20025
#                                                    147 rows omitted,"Secondary"=>147×6 DataFrame
#  Row │ year     age     education  fertility  pop       fx
#      │ Float64  String  String     Float64    Float64   Float64
# ─────┼────────────────────────────────────────────────────────────
#    1 │  1998.0  20--24  Secondary    58224.0   734.122   4.37338
#    2 │  1998.0  25--29  Secondary    45591.0   515.838   4.48167
#    3 │  1998.0  30--34  Secondary    27589.0   434.244   4.15157
#    4 │  1998.0  35--39  Secondary    11291.0   371.165   3.41511
#    5 │  1998.0  40--44  Secondary     1834.0   247.024   2.00477
#    6 │  1998.0  45--49  Secondary       87.0   154.046  -0.571343
#    7 │  1998.0  50--54  Secondary       41.0    97.316  -0.864391
#    8 │  1999.0  20--24  Secondary    65188.0   864.507   4.32287
#    9 │  1999.0  25--29  Secondary    48314.0   606.48    4.3778
#   10 │  1999.0  30--34  Secondary    29608.0   518.131   4.04557
#   11 │  1999.0  35--39  Secondary    12473.0   466.286   3.28652
#   ⋮  │    ⋮       ⋮         ⋮          ⋮         ⋮          ⋮
#  138 │  2017.0  40--44  Secondary     3341.0   474.401   1.95197
#  139 │  2017.0  45--49  Secondary      183.0   408.919  -0.804031
#  140 │  2017.0  50--54  Secondary       57.0   361.941  -1.84843
#  141 │  2018.0  20--24  Secondary    81685.0   905.778   4.50183
#  142 │  2018.0  25--29  Secondary    57207.0   789.344   4.28323
#  143 │  2018.0  30--34  Secondary    31556.0   667.071   3.85662
#  144 │  2018.0  35--39  Secondary    15585.0   591.926   3.27068
#  145 │  2018.0  40--44  Secondary     3554.0   462.893   2.03833
#  146 │  2018.0  45--49  Secondary      214.0   403.326  -0.633769
#  147 │  2018.0  50--54  Secondary       26.0   355.76   -2.61616
#                                                   126 rows omitted)

# %%
# Assuming mxjuliav1 is a vector of DataFrames
exf1 =  fxjuliav1_wide[1]
exf2 =  fxjuliav1_wide[2]
exf3 =  fxjuliav1_wide[3]
exf4 =  fxjuliav1_wide[4]
# Out:
# 6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  163.965   169.112   172.384   173.67    172.924   170.171   165.508    ⋯
#    2 │  173.682   177.848   180.736   182.279   182.444   181.227   178.655
#    3 │  157.622   149.233   143.512   140.182   139.084   140.165   143.477
#    4 │  122.391   119.229   118.039   118.763   121.437   126.191   133.266
#    5 │   79.852    81.93     85.117    89.54     95.377   102.87    112.346    ⋯
#    6 │   38.546    42.652    47.391    52.873    59.232    66.63     75.261
#                                                               14 columns omitted
