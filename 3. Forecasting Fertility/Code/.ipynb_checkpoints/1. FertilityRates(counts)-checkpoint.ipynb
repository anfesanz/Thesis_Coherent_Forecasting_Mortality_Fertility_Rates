# %%
using Turing, Distributions, RData, RCall, CSV, DataFrames, LinearAlgebra
# Function to filter out the specified age groups
function exclude_age_groups(df, ages_to_exclude)
    filter(row -> !(row[:age] in ages_to_exclude), df)
end

function replace_age_groups(dfs, age_map)
    for df in dfs
        df[!, :age] = [get(age_map, age, "0") for age in df[:, :age]]
    end
    return dfs
end

# Function to replace year with index
function replace_year_with_index(df)
    df[!, :year] = [year_to_index[year] for year in df[:, :year]]
    return df
end

# Function to unstack a DataFrame
function unstack_dataframe(df)
    # You might need to adjust the identifier columns as per your DataFrame structure
    identifier_cols = [ :education, :age]
    return unstack(df, identifier_cols, :year, :fertility)
end
# Out:
# unstack_dataframe (generic function with 1 method)

# %%
#Import rates
path1 = "/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/fxjuliav1.RData"
rates1 = load(path1)
# Out:
# Dict{String, Any} with 1 entry:
#   "fxjuliav1" => DictoVec{DataFrame}("No Education"=>168×6 DataFrame…

# %%
#Import rates
#mxjuliav1 and mxjuliav2 are created here
#/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year
#/Chapter Mortality/ModellingM/Code/2. BayesianLC/0. Main File BLC.R
path1 = "/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/fxjuliav1.RData"
rates1 = load(path1)

# Assigning 'mxjuliav' from 'rates'
fxjuliav1 = rates1["fxjuliav1"]
# Create an ordered list of keys as per your specified order
ordered_keys = [
    "No Education",
    "Primary",
    "Secondary",
    "Post Secondary"
]
# Ordered dataframe using the dictionary
fxjuliav1 = [fxjuliav1[key] for key in ordered_keys]

# Age groups to exclude
ages_to_exclude = ["15--19", "20--24", "55--59", "60--64", "65--69", "70--74", "75+"]
# Apply the filtering to each element in mxjuliav1
fxjuliav1 = [exclude_age_groups(df, ages_to_exclude) for df in fxjuliav1]

# Define the age mapping
age_map = Dict(
    "25--29" => "1",
    "30--34" => "2",
    "35--39" => "3",
    "40--44" => "4",
    "45--49" => "5",
    "50--54" => "6"
)
# Assuming mxjuliav1 is a list (or vector) of DataFrames
fxjuliav1 = replace_age_groups(fxjuliav1, age_map)

# Create a mapping from year to index
year_to_index = Dict(1998:2018 .=> 1:21)
# Apply the function to each DataFrame in your vector
fxjuliav1 = [replace_year_with_index(df) for df in fxjuliav1]


# Iterate through each DataFrame in the vector and drop 'mortality' and 'mx' columns
for df in fxjuliav1
    select!(df, Not([:pop, :fx]))
end

    
# Unstack each DataFrame in mxjuliav1
fxjuliav1_wide = [unstack_dataframe(df) for df in fxjuliav1]
    
    # Iterate through each DataFrame in the vector and drop 'mortality' and 'mx' columns
for df in fxjuliav1_wide
    select!(df, Not([ :education, :age]))
end

# %%
fxjuliav1_wide
# Out:
# 4-element Vector{DataFrame}:
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  29648.0   30199.0   29117.0   26290.0   24824.0   24211.0   24113.0    ⋯
#    2 │  20694.0   21697.0   21673.0   20581.0   19165.0   18763.0   18656.0
#    3 │  13516.0   14182.0   14054.0   13154.0   12845.0   12363.0   12315.0
#    4 │   4825.0    4872.0    5190.0    4922.0    4621.0    4692.0    4801.0
#    5 │    609.0     554.0     563.0     527.0     495.0     469.0     486.0    ⋯
#    6 │     41.0      42.0      48.0      37.0      26.0      37.0      50.0
#                                                               14 columns omitted
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  68545.0   68591.0   66191.0   60211.0   56898.0   55812.0   55556.0    ⋯
#    2 │  42729.0   44319.0   44398.0   41264.0   38510.0   38031.0   36452.0
#    3 │  20618.0   22226.0   22497.0   21544.0   20902.0   20882.0   20726.0
#    4 │   4577.0    5176.0    5389.0    5599.0    5451.0    5629.0    6038.0
#    5 │    346.0     417.0     396.0     372.0     417.0     405.0     402.0    ⋯
#    6 │     55.0      53.0      66.0      40.0      20.0      30.0      62.0
#                                                               14 columns omitted
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  45591.0   48314.0   49494.0   48596.0   49284.0   53098.0   57330.0    ⋯
#    2 │  27589.0   29608.0   30224.0   29638.0   29472.0   30193.0   31156.0
#    3 │  11291.0   12473.0   13065.0   12943.0   13122.0   13586.0   14571.0
#    4 │   1834.0    2104.0    2319.0    2417.0    2595.0    2806.0    3048.0
#    5 │     87.0      99.0     147.0     135.0     142.0     145.0     174.0    ⋯
#    6 │     41.0      35.0      41.0      17.0      15.0      17.0      58.0
#                                                               14 columns omitted
#  6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  13271.0   14062.0   14245.0   14260.0   14600.0   15569.0   17025.0    ⋯
#    2 │  14646.0   15084.0   15489.0   14844.0   14907.0   15522.0   16171.0
#    3 │   7021.0    7699.0    8236.0    8162.0    8361.0    8791.0    9241.0
#    4 │   1228.0    1376.0    1512.0    1570.0    1608.0    1749.0    1982.0
#    5 │     49.0      58.0      77.0      71.0      68.0     107.0      86.0    ⋯
#    6 │     17.0      13.0      15.0       5.0       9.0       5.0      20.0
#                                                               14 columns omitted

# %%
fxjuliav1
# Out:
# 4-element Vector{DataFrame}:
#  126×4 DataFrame
#  Row │ year   age     education     fertility
#      │ Int64  String  String        Float64
# ─────┼────────────────────────────────────────
#    1 │     1  1       No Education    29648.0
#    2 │     1  2       No Education    20694.0
#    3 │     1  3       No Education    13516.0
#    4 │     1  4       No Education     4825.0
#    5 │     1  5       No Education      609.0
#    6 │     1  6       No Education       41.0
#    7 │     2  1       No Education    30199.0
#    8 │     2  2       No Education    21697.0
#    9 │     2  3       No Education    14182.0
#   10 │     2  4       No Education     4872.0
#   11 │     2  5       No Education      554.0
#   ⋮  │   ⋮      ⋮          ⋮            ⋮
#  117 │    20  3       No Education     1421.0
#  118 │    20  4       No Education      558.0
#  119 │    20  5       No Education       93.0
#  120 │    20  6       No Education        4.0
#  121 │    21  1       No Education     2006.0
#  122 │    21  2       No Education     1798.0
#  123 │    21  3       No Education     1337.0
#  124 │    21  4       No Education      542.0
#  125 │    21  5       No Education       77.0
#  126 │    21  6       No Education       13.0
#                               105 rows omitted
#  126×4 DataFrame
#  Row │ year   age     education  fertility
#      │ Int64  String  String     Float64
# ─────┼─────────────────────────────────────
#    1 │     1  1       Primary      68545.0
#    2 │     1  2       Primary      42729.0
#    3 │     1  3       Primary      20618.0
#    4 │     1  4       Primary       4577.0
#    5 │     1  5       Primary        346.0
#    6 │     1  6       Primary         55.0
#    7 │     2  1       Primary      68591.0
#    8 │     2  2       Primary      44319.0
#    9 │     2  3       Primary      22226.0
#   10 │     2  4       Primary       5176.0
#   11 │     2  5       Primary        417.0
#   ⋮  │   ⋮      ⋮         ⋮          ⋮
#  117 │    20  3       Primary      15574.0
#  118 │    20  4       Primary       4725.0
#  119 │    20  5       Primary        409.0
#  120 │    20  6       Primary         44.0
#  121 │    21  1       Primary      39731.0
#  122 │    21  2       Primary      26110.0
#  123 │    21  3       Primary      15012.0
#  124 │    21  4       Primary       4772.0
#  125 │    21  5       Primary        395.0
#  126 │    21  6       Primary         30.0
#                            105 rows omitted
#  126×4 DataFrame
#  Row │ year   age     education  fertility
#      │ Int64  String  String     Float64
# ─────┼─────────────────────────────────────
#    1 │     1  1       Secondary    45591.0
#    2 │     1  2       Secondary    27589.0
#    3 │     1  3       Secondary    11291.0
#    4 │     1  4       Secondary     1834.0
#    5 │     1  5       Secondary       87.0
#    6 │     1  6       Secondary       41.0
#    7 │     2  1       Secondary    48314.0
#    8 │     2  2       Secondary    29608.0
#    9 │     2  3       Secondary    12473.0
#   10 │     2  4       Secondary     2104.0
#   11 │     2  5       Secondary       99.0
#   ⋮  │   ⋮      ⋮         ⋮          ⋮
#  117 │    20  3       Secondary    15801.0
#  118 │    20  4       Secondary     3341.0
#  119 │    20  5       Secondary      183.0
#  120 │    20  6       Secondary       57.0
#  121 │    21  1       Secondary    57207.0
#  122 │    21  2       Secondary    31556.0
#  123 │    21  3       Secondary    15585.0
#  124 │    21  4       Secondary     3554.0
#  125 │    21  5       Secondary      214.0
#  126 │    21  6       Secondary       26.0
#                            105 rows omitted
#  126×4 DataFrame
#  Row │ year   age     education       fertility
#      │ Int64  String  String          Float64
# ─────┼──────────────────────────────────────────
#    1 │     1  1       Post Secondary    13271.0
#    2 │     1  2       Post Secondary    14646.0
#    3 │     1  3       Post Secondary     7021.0
#    4 │     1  4       Post Secondary     1228.0
#    5 │     1  5       Post Secondary       49.0
#    6 │     1  6       Post Secondary       17.0
#    7 │     2  1       Post Secondary    14062.0
#    8 │     2  2       Post Secondary    15084.0
#    9 │     2  3       Post Secondary     7699.0
#   10 │     2  4       Post Secondary     1376.0
#   11 │     2  5       Post Secondary       58.0
#   ⋮  │   ⋮      ⋮           ⋮             ⋮
#  117 │    20  3       Post Secondary    22303.0
#  118 │    20  4       Post Secondary     4264.0
#  119 │    20  5       Post Secondary      269.0
#  120 │    20  6       Post Secondary       34.0
#  121 │    21  1       Post Secondary    51267.0
#  122 │    21  2       Post Secondary    41195.0
#  123 │    21  3       Post Secondary    22775.0
#  124 │    21  4       Post Secondary     4482.0
#  125 │    21  5       Post Secondary      252.0
#  126 │    21  6       Post Secondary       46.0
#                                 105 rows omitted

# %%
# Assuming mxjuliav1 is a vector of DataFrames
# Assuming mxjuliav1 is a vector of DataFrames
fx1 =  mxjuliav1_wide[1]
fx2 =  mxjuliav1_wide[2]
fx3 =  mxjuliav1_wide[3]
fx4 =  mxjuliav1_wide[4]
# Out:
# 6×21 DataFrame
#  Row │ 1         2         3         4         5         6         7         8 ⋯
#      │ Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  Float64?  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  163.965   169.112   172.384   173.67    172.924   170.171   165.508    ⋯
#    2 │  173.682   177.848   180.736   182.279   182.444   181.227   178.655
#    3 │  157.622   149.233   143.512   140.182   139.084   140.165   143.477
#    4 │  122.391   119.229   118.039   118.763   121.437   126.191   133.266
#    5 │   79.852    81.93     85.117    89.54     95.377   102.87    112.346    ⋯
#    6 │   38.546    42.652    47.391    52.873    59.232    66.63     75.261
#                                                               14 columns omitted

# %%
CSV.write("/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/exfe1.csv", exfe1)
CSV.write("/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/exfe2.csv", exfe2)
CSV.write("/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/exfe3.csv", exfe3)
CSV.write("/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/exfe4.csv", exfe4)
# Out:
# "/Users/felipesanchez/Documents/UoM/PhD/Phd Third Year/Chapter Fertility/ModellingF/Data_Created/exfe4.csv"
